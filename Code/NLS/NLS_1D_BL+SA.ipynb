# %% [markdown]
# # PINN Solution of the Nonlinear Shroedinger PDE
#
# This PyTorch code demonstrates the application of physically-informed neural networks (PINN) in the solution of a well-known Nonlinear Shroedinger PDE with periodic boundary condition
# \begin{aligned}
#   &\mathbf{u}_t = i * \mathbf{u}_{xx} + i * |\mathbf{u}|^2 * \mathbf{u} \in [0, T]\times[-L, L]\\
#   &\mathbf{u}(0, x) = \mathbf{u}_0(x), \quad \forall x \in [-L, L] \\
#   &\mathbf{u}(t, -L) = \mathbf{u}(t, L), \quad \forall t \in [0, T]
# \end{aligned}
# where $i^2 = -1$, and $[-L, L]$ covers one full period, i.e. $T = 2L$.  If we let $\mathbf{u} = u + i * v$, then we obtain two PDEs
# \begin{aligned}
# u_t &= -v_{xx} - (u^2 + v^2) * v \\
# v_t &= u_{xx} + (u^2 + v^2) * u
# \end{aligned}

# %% [markdown]
# ## Libraries and Dependencies

# %%
import torch
import torch.optim
import torch.optim.lr_scheduler as lr_scheduler
from itertools import chain
from collections import OrderedDict
from pyDOE import lhs
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy.io
from scipy.interpolate import griddata
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.gridspec as gridspec
import time
# set the random seed
np.random.seed(1234)

# %%
if torch.backends.mps.is_available():
    device = torch.device('mps')
elif torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
#
print(f"Working on {device}")
# Out:
# Working on mps

# %%
L = np.pi
xlo = -L
xhi = L
period = xhi - xlo
tlo = 0.0
thi = 2.0
sqrt2 = torch.tensor(np.sqrt(2)).float().to(device)
# taking A = 1 and B = 1
u0_ten = lambda x: 2.0/(2.0 - sqrt2 * torch.cos(x)) - 1.0
v0_ten = lambda x: torch.zeros_like(x)

# %% [markdown]
# ## Physics-informed Neural Networks

# %%
# the deep neural network
class DNN(torch.nn.Module):
    def __init__(self, layers):
        super(DNN, self).__init__()
        # parameters
        self.depth = len(layers) - 1
        # set up layer order dict
        self.activation = torch.nn.Tanh
        layer_list = list()
        for i in range(self.depth - 1): 
            layer_list.append(
                ('layer_%d' % i, torch.nn.Linear(layers[i], layers[i+1]))
            )
            layer_list.append(('activation_%d' % i, self.activation()))
            
        layer_list.append(
            ('layer_%d' % (self.depth - 1), torch.nn.Linear(layers[-2], layers[-1]))
        )
        layerDict = OrderedDict(layer_list)
        # deploy layers
        self.layers = torch.nn.Sequential(layerDict)
        self.layers[0].weight = torch.load('initial_weight.pt')
    def forward(self, x):
        out = self.layers(x)
        return out

# %%
class PhysicsInformedNN():
    def __init__(self, period, X_IC, u_IC, v_IC, X_BC, u_BC, v_BC, X_PDE, layers):
        # IC data point
        self.t_IC = torch.tensor(X_IC[:, 0:1]).float().to(device)
        self.x_IC = torch.tensor(X_IC[:, 1:2]).float().to(device)
        self.u_IC = torch.tensor(u_IC).float().to(device)
        self.v_IC = torch.tensor(v_IC).float().to(device) 
        N_IC = X_IC.shape[0]
        self.LW_uIC = torch.nn.ParameterList([torch.nn.Parameter(torch.ones(N_IC, 1).float(), requires_grad=True).to(device)])
        self.LW_vIC = torch.nn.ParameterList([torch.nn.Parameter(torch.ones(N_IC, 1).float(), requires_grad=True).to(device)])
        # BC data point
        self.t_BC = torch.tensor(X_BC[:, 0:1]).float().to(device)
        self.x_BC = torch.tensor(X_BC[:, 1:2]).float().to(device)
        self.u_BC = torch.tensor(u_BC).float().to(device)
        self.v_BC = torch.tensor(v_BC).float().to(device) 
        self.period = torch.tensor(period).float().to(device)
        N_BC = X_BC.shape[0]
        self.LW_uBC = torch.nn.ParameterList([torch.nn.Parameter(torch.ones(N_BC, 1).float(), requires_grad=True).to(device)])        
        self.LW_vBC = torch.nn.ParameterList([torch.nn.Parameter(torch.ones(N_BC, 1).float(), requires_grad=True).to(device)])        
        # PDE data, gradients will be computed on these points so requires_grad = True
        self.t_PDE = torch.tensor(X_PDE[:, 0:1], requires_grad=True).float().to(device)
        self.x_PDE = torch.tensor(X_PDE[:, 1:2], requires_grad=True).float().to(device)
       
        N_PDE = X_PDE.shape[0]
        self.LW_uPDE = torch.nn.ParameterList([torch.nn.Parameter(torch.ones(N_PDE, 1).float(), requires_grad=True).to(device)])
        self.LW_vPDE = torch.nn.ParameterList([torch.nn.Parameter(torch.ones(N_PDE, 1).float(), requires_grad=True).to(device)])

        
        # layers to build Neural Net
        self.layers = layers
        # deep neural networks
        self.dnn = DNN(layers).to(device)    
        # prepare the optimizer
        self.optimizer_Adam = torch.optim.Adam(self.dnn.parameters(), lr = 1e-3)
        self.optimizer_LW_uIC = torch.optim.Adam(self.LW_uIC.parameters(), lr = 5e-3)
        self.optimizer_LW_uBC = torch.optim.Adam(self.LW_uBC.parameters(), lr = 5e-3)
        self.optimizer_LW_uPDE = torch.optim.Adam(self.LW_uPDE.parameters(), lr = 5e-3)
        self.optimizer_LW_vIC = torch.optim.Adam(self.LW_vIC.parameters(), lr = 5e-3)
        self.optimizer_LW_vBC = torch.optim.Adam(self.LW_vBC.parameters(), lr = 5e-3)
        self.optimizer_LW_vPDE = torch.optim.Adam(self.LW_vPDE.parameters(), lr = 5e-3)
        # add a learning rate scheduler
        
        self.optimizer_LBFGS = torch.optim.LBFGS(
            self.dnn.parameters(), 
            lr=1.0, 
            max_iter=50000, 
            max_eval=50000, 
            history_size=50,
            tolerance_grad=1e-8, 
            tolerance_change=1.0 * np.finfo(float).eps,
            line_search_fn="strong_wolfe"       # can be "strong_wolfe"
        )        
        self.scheduler = lr_scheduler.ExponentialLR(self.optimizer_Adam, gamma=0.999)
        self.iter = 0
    # evaluater neural network, no transformation
    def NN_eval(self, t, x):  
        NN = self.dnn(torch.cat([t, x], dim = 1)) 
        u = NN[:, 0][:, None]
        v = NN[:, 1][:, None]
        return u,v
    # compute the PDE
    def pde_eval(self, t, x):
        """ The pytorch autograd version of calculating residual """
        u, v = self.NN_eval(t, x)
        # compute the derivatives for u
        u_t    = torch.autograd.grad(u,     t, grad_outputs = torch.ones_like(u), retain_graph = True, create_graph=True)[0]
        u_x    = torch.autograd.grad(u,     x, grad_outputs = torch.ones_like(u), retain_graph = True, create_graph=True)[0]
        u_xx   = torch.autograd.grad(u_x,   x, grad_outputs = torch.ones_like(u), retain_graph = True, create_graph=True)[0]
        v_t    = torch.autograd.grad(v,     t, grad_outputs = torch.ones_like(u), retain_graph = True, create_graph=True)[0]
        v_x    = torch.autograd.grad(v,     x, grad_outputs = torch.ones_like(u), retain_graph = True, create_graph=True)[0]
        v_xx   = torch.autograd.grad(v_x,   x, grad_outputs = torch.ones_like(u), retain_graph = True, create_graph=True)[0]   
        # pre-compute the norm of \mathbf{u}, so that it can be re-used
        U_norm = torch.pow(u, 2.0) + torch.pow(v, 2.0)
        Eq1    = u_t + v_xx + U_norm * v
        Eq2    = v_t - u_xx - U_norm * u
        return Eq1, Eq2
    # compute the total loss for the second-order optimizer
    def loss_func(self):
        # reset the gradient
        self.optimizer_LBFGS.zero_grad()
        # compute IC loss
        uIC_pred, vIC_pred = self.NN_eval(self.t_IC, self.x_IC)
    
        loss_IC = torch.mean((self.LW_uIC[0] *(self.u_IC - uIC_pred))**2.0) + torch.mean((self.LW_vIC[0] *(self.v_IC - vIC_pred))**2.0)
        # compute PBC loss
        uBC_pred_left, vBC_pred_left = self.NN_eval(self.t_BC, self.x_BC)
        uBC_pred_right, vBC_pred_right = self.NN_eval(self.t_BC, self.x_BC+self.period)
        loss_BC = torch.mean((self.LW_uBC[0]*(uBC_pred_left - uBC_pred_right))**2.0) + torch.mean((self.LW_vBC[0]*(vBC_pred_left - vBC_pred_right))**2.0)
        
        
        pde1_pred, pde2_pred = self.pde_eval(self.t_PDE, self.x_PDE)
        loss_PDE = torch.mean((self.LW_uPDE[0]*pde1_pred )** 2) + torch.mean((self.LW_vPDE[0]*pde2_pred )** 2)   
        
       
        # compute the total loss, it can be weighted
        loss = loss_IC + loss_BC + loss_PDE
        # backward propagation
        loss.backward()
        # increase the iteration counter
        self.iter += 1
        # output
        # output the progress
        if self.iter % 1000 == 0:
            end_time = time.time()
            print('Iter %5d, Total: %10.4e, Time: %.2f secs' % (self.iter, loss.item(), end_time - self.start_time))
            print('IC: %10.4e, PBC: %10.4e, PDE: %10.4e' % (loss_IC.item(), loss_BC.item(), loss_PDE.item()))
            self.start_time = end_time
        return loss
    #
    def train(self, nIter):
        # start the timer
        start_time = time.time()        
        # start the training with Adam first
        self.dnn.train()
        print('Starting with Adam')
        for epoch in range(nIter):
            # compute IC loss
            uIC_pred, vIC_pred = self.NN_eval(self.t_IC, self.x_IC)
    
            loss_IC = torch.mean((self.LW_uIC[0] *(self.u_IC - uIC_pred))**2.0) + torch.mean((self.LW_vIC[0] *(self.v_IC - vIC_pred))**2.0)
        # compute PBC loss
            uBC_pred_left, vBC_pred_left = self.NN_eval(self.t_BC, self.x_BC)
            uBC_pred_right, vBC_pred_right = self.NN_eval(self.t_BC, self.x_BC+self.period)
            loss_BC = torch.mean((self.LW_uBC[0]*(uBC_pred_left - uBC_pred_right))**2.0) + torch.mean((self.LW_vBC[0]*(vBC_pred_left - vBC_pred_right))**2.0)
        
        
            pde1_pred, pde2_pred = self.pde_eval(self.t_PDE, self.x_PDE)
            loss_PDE = torch.mean((self.LW_uPDE[0]*pde1_pred )** 2) + torch.mean((self.LW_vPDE[0]*pde2_pred )** 2)   
        
       
        # compute the total loss, it can be weighted
            loss = loss_IC + loss_BC + loss_PDE
            # Backward and optimize
            self.optimizer_Adam.zero_grad()
            self.optimizer_LW_uIC.zero_grad()
            self.optimizer_LW_uBC.zero_grad()
            self.optimizer_LW_uPDE.zero_grad()
            self.optimizer_LW_vIC.zero_grad()
            self.optimizer_LW_vBC.zero_grad()
            self.optimizer_LW_vPDE.zero_grad()
            loss.backward()
            self.optimizer_Adam.step() 
            self.LW_uIC[0].grad.data = -self.LW_uIC[0].grad.data
            self.LW_uBC[0].grad.data = -self.LW_uBC[0].grad.data
            self.LW_uPDE[0].grad.data = -self.LW_uPDE[0].grad.data
            self.LW_vIC[0].grad.data = -self.LW_vIC[0].grad.data
            self.LW_vBC[0].grad.data = -self.LW_vBC[0].grad.data
            self.LW_vPDE[0].grad.data = -self.LW_vPDE[0].grad.data
            self.optimizer_LW_uIC.step()
            self.optimizer_LW_uBC.step()
            self.optimizer_LW_uPDE.step()
            self.optimizer_LW_vIC.step()
            self.optimizer_LW_vBC.step()
            self.optimizer_LW_vPDE.step()
            # output the progress
            if (epoch + 1) % 1000 == 0:
                end_time = time.time()
                print('Iter %5d, Total: %10.4e, Time: %.2f secs' % (epoch + 1, loss.item(), end_time - start_time))
                print('IC: %10.4e, PBC: %10.4e, PDE: %10.4e' % (loss_IC.item(), loss_BC.item(), loss_PDE.item()))
                print('For uIC,  min uLW: %10.4e, max uLW: %10.4e' %(torch.min(self.LW_uIC[0]).item(), torch.max(self.LW_uIC[0]).item()))
                print('For uBC,  min uLW: %10.4e, max uLW: %10.4e' %(torch.min(self.LW_uBC[0]).item(), torch.max(self.LW_uBC[0]).item()))
                print('For uPDE, min uLW: %10.4e, max uLW: %10.4e' %(torch.min(self.LW_uPDE[0]).item(), torch.max(self.LW_uPDE[0]).item()))
                print('For vIC,  min vLW: %10.4e, max vLW: %10.4e' %(torch.min(self.LW_vIC[0]).item(), torch.max(self.LW_vIC[0]).item()))
                print('For vBC,  min vLW: %10.4e, max vLW: %10.4e' %(torch.min(self.LW_vBC[0]).item(), torch.max(self.LW_vBC[0]).item()))
                print('For vPDE, min vLW: %10.4e, max vLW: %10.4e' %(torch.min(self.LW_vPDE[0]).item(), torch.max(self.LW_vPDE[0]).item()))
                
                start_time = end_time
                # change the learning rate
                self.scheduler.step()
        # Using the second-order L-BFGS optimizer
        print('Starting with L-BFGS')
        self.start_time = time.time()
        self.optimizer_LBFGS.step(self.loss_func)                
    #        
    def predict(self, X):
        t = torch.tensor(X[:, 0:1], requires_grad=True).float().to(device)
        x = torch.tensor(X[:, 1:2], requires_grad=True).float().to(device)
        self.dnn.eval()
        u, v = self.NN_eval(t, x)
        u = u.detach().cpu().numpy()
        v = v.detach().cpu().numpy()
        return u,v


## Configurations

# %% [markdown]
# ## Training

# %%
layers = [2, 32, 32, 32, 32, 32, 32, 32, 2]
N_IC = 96
ptsIC=np.load('ptsIC.npy')
ptsBC=np.load('ptsBC.npy')
ptsPDE=np.load('random_data.npy')
uBC = np.load('uBC.npy')
vBC = np.load('vBC.npy')
x_IC = np.expand_dims(np.linspace(xlo, xhi, N_IC), axis = 1)
uIC = u0(x_IC)
vIC = v0(x_IC)
model = PhysicsInformedNN(period, ptsIC, uIC, vIC, ptsBC, uBC, vBC, ptsPDE, layers)
model.train(50000)
# Out:
# Starting with Adam
# Iter  1000, Total: 2.0258e-03, Time: 46.69 secs
# IC: 8.5185e-04, PBC: 7.5804e-05, PDE: 1.0982e-03
# For uIC,  min uLW: 1.1006e+00, max uLW: 1.1525e+00
# For uBC,  min uLW: 1.0787e+00, max uLW: 1.5474e+00
# For uPDE, min uLW: 1.0924e+00, max uLW: 2.7164e+00
# For vIC,  min vLW: 1.0944e+00, max vLW: 1.1974e+00
# For vBC,  min vLW: 1.1094e+00, max vLW: 1.3172e+00
# For vPDE, min vLW: 1.0833e+00, max vLW: 1.5446e+00
# Iter  2000, Total: 1.5214e-03, Time: 47.68 secs
# IC: 3.9260e-04, PBC: 4.4079e-05, PDE: 1.0847e-03
# For uIC,  min uLW: 1.1006e+00, max uLW: 1.1529e+00
# For uBC,  min uLW: 1.0795e+00, max uLW: 1.5733e+00
# For uPDE, min uLW: 1.0932e+00, max uLW: 3.2680e+00
# For vIC,  min vLW: 1.0944e+00, max vLW: 1.1975e+00
# For vBC,  min vLW: 1.1120e+00, max vLW: 1.3662e+00
# For vPDE, min vLW: 1.0834e+00, max vLW: 1.8829e+00
# Iter  3000, Total: 1.3360e-03, Time: 48.08 secs
# IC: 2.8123e-04, PBC: 3.0121e-05, PDE: 1.0246e-03
# For uIC,  min uLW: 1.1006e+00, max uLW: 1.1531e+00
# For uBC,  min uLW: 1.0805e+00, max uLW: 1.5918e+00
# For uPDE, min uLW: 1.0971e+00, max uLW: 3.8583e+00
# For vIC,  min vLW: 1.0945e+00, max vLW: 1.1977e+00
# For vBC,  min vLW: 1.1137e+00, max vLW: 1.3885e+00
# For vPDE, min vLW: 1.0836e+00, max vLW: 2.1248e+00
# Iter  4000, Total: 1.1821e-03, Time: 47.54 secs
# IC: 2.1754e-04, PBC: 2.2928e-05, PDE: 9.4160e-04
# For uIC,  min uLW: 1.1006e+00, max uLW: 1.1532e+00
# For uBC,  min uLW: 1.0828e+00, max uLW: 1.6058e+00
# For uPDE, min uLW: 1.0996e+00, max uLW: 4.4077e+00
# For vIC,  min vLW: 1.0946e+00, max vLW: 1.1982e+00
# For vBC,  min vLW: 1.1245e+00, max vLW: 1.3967e+00
# For vPDE, min vLW: 1.0837e+00, max vLW: 2.2845e+00
# Iter  5000, Total: 1.0044e-03, Time: 46.35 secs
# IC: 1.7825e-04, PBC: 1.6531e-05, PDE: 8.0961e-04
# For uIC,  min uLW: 1.1006e+00, max uLW: 1.1532e+00
# For uBC,  min uLW: 1.0837e+00, max uLW: 1.6147e+00
# For uPDE, min uLW: 1.1002e+00, max uLW: 4.8077e+00
# For vIC,  min vLW: 1.0948e+00, max vLW: 1.1987e+00
# For vBC,  min vLW: 1.1301e+00, max vLW: 1.4028e+00
# For vPDE, min vLW: 1.0838e+00, max vLW: 2.3870e+00
# Iter  6000, Total: 7.4022e-04, Time: 47.59 secs
# IC: 1.6400e-04, PBC: 1.8874e-05, PDE: 5.5735e-04
# For uIC,  min uLW: 1.1006e+00, max uLW: 1.1533e+00
# For uBC,  min uLW: 1.0845e+00, max uLW: 1.6173e+00
# For uPDE, min uLW: 1.1006e+00, max uLW: 5.0336e+00
# For vIC,  min vLW: 1.0950e+00, max vLW: 1.1993e+00
# For vBC,  min vLW: 1.1310e+00, max vLW: 1.4101e+00
# For vPDE, min vLW: 1.0838e+00, max vLW: 2.4503e+00
# Iter  7000, Total: 5.0296e-04, Time: 48.03 secs
# IC: 1.3231e-04, PBC: 1.8814e-05, PDE: 3.5184e-04
# For uIC,  min uLW: 1.1006e+00, max uLW: 1.1533e+00
# For uBC,  min uLW: 1.0851e+00, max uLW: 1.6187e+00
# For uPDE, min uLW: 1.1011e+00, max uLW: 5.1355e+00
# For vIC,  min vLW: 1.0953e+00, max vLW: 1.2005e+00
# For vBC,  min vLW: 1.1490e+00, max vLW: 1.4134e+00
# For vPDE, min vLW: 1.0838e+00, max vLW: 2.4863e+00
# Iter  8000, Total: 3.8425e-04, Time: 46.56 secs
# IC: 1.0362e-04, PBC: 1.6490e-05, PDE: 2.6414e-04
# For uIC,  min uLW: 1.1006e+00, max uLW: 1.1533e+00
# For uBC,  min uLW: 1.0851e+00, max uLW: 1.6190e+00
# For uPDE, min uLW: 1.1011e+00, max uLW: 5.1745e+00
# For vIC,  min vLW: 1.0955e+00, max vLW: 1.2022e+00
# For vBC,  min vLW: 1.1644e+00, max vLW: 1.4135e+00
# For vPDE, min vLW: 1.0839e+00, max vLW: 2.5051e+00
# Iter  9000, Total: 2.5661e-04, Time: 46.23 secs
# IC: 7.5589e-05, PBC: 1.1606e-05, PDE: 1.6942e-04
# For uIC,  min uLW: 1.1007e+00, max uLW: 1.1533e+00
# For uBC,  min uLW: 1.0858e+00, max uLW: 1.6191e+00
# For uPDE, min uLW: 1.1011e+00, max uLW: 5.1900e+00
# For vIC,  min vLW: 1.0956e+00, max vLW: 1.2040e+00
# For vBC,  min vLW: 1.1652e+00, max vLW: 1.4141e+00
# For vPDE, min vLW: 1.0841e+00, max vLW: 2.5144e+00
# Iter 10000, Total: 1.9171e-04, Time: 47.70 secs
# IC: 6.2623e-05, PBC: 7.2122e-06, PDE: 1.2187e-04
# For uIC,  min uLW: 1.1008e+00, max uLW: 1.1533e+00
# For uBC,  min uLW: 1.0885e+00, max uLW: 1.6192e+00
# For uPDE, min uLW: 1.1013e+00, max uLW: 5.1962e+00
# For vIC,  min vLW: 1.0957e+00, max vLW: 1.2057e+00
# For vBC,  min vLW: 1.1673e+00, max vLW: 1.4142e+00
# For vPDE, min vLW: 1.0841e+00, max vLW: 2.5180e+00
# Iter 11000, Total: 1.5383e-04, Time: 48.64 secs
# IC: 5.3669e-05, PBC: 4.6509e-06, PDE: 9.5508e-05
# For uIC,  min uLW: 1.1009e+00, max uLW: 1.1533e+00
# For uBC,  min uLW: 1.0914e+00, max uLW: 1.6193e+00
# For uPDE, min uLW: 1.1014e+00, max uLW: 5.1991e+00
# For vIC,  min vLW: 1.0958e+00, max vLW: 1.2077e+00
# For vBC,  min vLW: 1.1694e+00, max vLW: 1.4142e+00
# For vPDE, min vLW: 1.0841e+00, max vLW: 2.5195e+00
# Iter 12000, Total: 1.2564e-04, Time: 47.84 secs
# IC: 4.6367e-05, PBC: 2.7757e-06, PDE: 7.6501e-05
# For uIC,  min uLW: 1.1011e+00, max uLW: 1.1533e+00
# For uBC,  min uLW: 1.0926e+00, max uLW: 1.6193e+00
# For uPDE, min uLW: 1.1014e+00, max uLW: 5.2006e+00
# For vIC,  min vLW: 1.0958e+00, max vLW: 1.2101e+00
# For vBC,  min vLW: 1.1700e+00, max vLW: 1.4142e+00
# For vPDE, min vLW: 1.0841e+00, max vLW: 2.5204e+00
# Iter 13000, Total: 8.9027e-04, Time: 48.27 secs
# IC: 2.7437e-04, PBC: 6.2543e-05, PDE: 5.5336e-04
# For uIC,  min uLW: 1.2488e+00, max uLW: 1.8114e+00
# For uBC,  min uLW: 1.3239e+00, max uLW: 1.8380e+00
# For uPDE, min uLW: 1.1204e+00, max uLW: 5.8454e+00
# For vIC,  min vLW: 1.4147e+00, max vLW: 1.9397e+00
# For vBC,  min vLW: 1.5072e+00, max vLW: 1.7639e+00
# For vPDE, min vLW: 1.0917e+00, max vLW: 2.6708e+00
# Iter 14000, Total: 6.0192e-04, Time: 47.84 secs
# IC: 1.7042e-04, PBC: 4.7084e-05, PDE: 3.8441e-04
# For uIC,  min uLW: 1.2493e+00, max uLW: 1.8147e+00
# For uBC,  min uLW: 1.3239e+00, max uLW: 1.8384e+00
# For uPDE, min uLW: 1.1204e+00, max uLW: 5.8941e+00
# For vIC,  min vLW: 1.4152e+00, max vLW: 1.9408e+00
# For vBC,  min vLW: 1.5078e+00, max vLW: 1.7662e+00
# For vPDE, min vLW: 1.0918e+00, max vLW: 2.6795e+00
# Iter 15000, Total: 4.5066e-04, Time: 47.08 secs
# IC: 1.3289e-04, PBC: 3.6510e-05, PDE: 2.8127e-04
# For uIC,  min uLW: 1.2497e+00, max uLW: 1.8166e+00
# For uBC,  min uLW: 1.3239e+00, max uLW: 1.8389e+00
# For uPDE, min uLW: 1.1205e+00, max uLW: 5.9111e+00
# For vIC,  min vLW: 1.4155e+00, max vLW: 1.9414e+00
# For vBC,  min vLW: 1.5079e+00, max vLW: 1.7684e+00
# For vPDE, min vLW: 1.0920e+00, max vLW: 2.6828e+00
# Iter 16000, Total: 3.4759e-04, Time: 47.60 secs
# IC: 1.0797e-04, PBC: 2.9160e-05, PDE: 2.1046e-04
# For uIC,  min uLW: 1.2501e+00, max uLW: 1.8180e+00
# For uBC,  min uLW: 1.3239e+00, max uLW: 1.8394e+00
# For uPDE, min uLW: 1.1208e+00, max uLW: 5.9170e+00
# For vIC,  min vLW: 1.4156e+00, max vLW: 1.9418e+00
# For vBC,  min vLW: 1.5079e+00, max vLW: 1.7700e+00
# For vPDE, min vLW: 1.0922e+00, max vLW: 2.6844e+00
# Iter 17000, Total: 2.7836e-04, Time: 47.68 secs
# IC: 9.4265e-05, PBC: 2.3306e-05, PDE: 1.6079e-04
# For uIC,  min uLW: 1.2509e+00, max uLW: 1.8190e+00
# For uBC,  min uLW: 1.3239e+00, max uLW: 1.8400e+00
# For uPDE, min uLW: 1.1222e+00, max uLW: 5.9182e+00
# For vIC,  min vLW: 1.4157e+00, max vLW: 1.9420e+00
# For vBC,  min vLW: 1.5079e+00, max vLW: 1.7713e+00
# For vPDE, min vLW: 1.0924e+00, max vLW: 2.6853e+00
# Iter 18000, Total: 2.2899e-04, Time: 47.04 secs
# IC: 8.7585e-05, PBC: 1.7984e-05, PDE: 1.2342e-04
# For uIC,  min uLW: 1.2522e+00, max uLW: 1.8197e+00
# For uBC,  min uLW: 1.3239e+00, max uLW: 1.8407e+00
# For uPDE, min uLW: 1.1229e+00, max uLW: 5.9183e+00
# For vIC,  min vLW: 1.4158e+00, max vLW: 1.9421e+00
# For vBC,  min vLW: 1.5079e+00, max vLW: 1.7721e+00
# For vPDE, min vLW: 1.0925e+00, max vLW: 2.6858e+00
# Iter 19000, Total: 1.8414e-04, Time: 48.76 secs
# IC: 7.7611e-05, PBC: 1.2157e-05, PDE: 9.4375e-05
# For uIC,  min uLW: 1.2542e+00, max uLW: 1.8199e+00
# For uBC,  min uLW: 1.3239e+00, max uLW: 1.8413e+00
# For uPDE, min uLW: 1.1235e+00, max uLW: 5.9185e+00
# For vIC,  min vLW: 1.4160e+00, max vLW: 1.9454e+00
# For vBC,  min vLW: 1.5079e+00, max vLW: 1.7727e+00
# For vPDE, min vLW: 1.0925e+00, max vLW: 2.6862e+00
# Iter 20000, Total: 1.5502e-04, Time: 48.45 secs
# IC: 7.1486e-05, PBC: 6.5476e-06, PDE: 7.6987e-05
# For uIC,  min uLW: 1.2573e+00, max uLW: 1.8200e+00
# For uBC,  min uLW: 1.3239e+00, max uLW: 1.8416e+00
# For uPDE, min uLW: 1.1242e+00, max uLW: 5.9194e+00
# For vIC,  min vLW: 1.4162e+00, max vLW: 1.9576e+00
# For vBC,  min vLW: 1.5079e+00, max vLW: 1.7730e+00
# For vPDE, min vLW: 1.0925e+00, max vLW: 2.6865e+00
# Iter 21000, Total: 1.3542e-04, Time: 48.52 secs
# IC: 6.7620e-05, PBC: 3.3877e-06, PDE: 6.4410e-05
# For uIC,  min uLW: 1.2616e+00, max uLW: 1.8202e+00
# For uBC,  min uLW: 1.3239e+00, max uLW: 1.8419e+00
# For uPDE, min uLW: 1.1248e+00, max uLW: 5.9202e+00
# For vIC,  min vLW: 1.4165e+00, max vLW: 1.9724e+00
# For vBC,  min vLW: 1.5079e+00, max vLW: 1.7732e+00
# For vPDE, min vLW: 1.0925e+00, max vLW: 2.6870e+00
# Iter 22000, Total: 1.1991e-04, Time: 48.04 secs
# IC: 6.3798e-05, PBC: 1.8360e-06, PDE: 5.4277e-05
# For uIC,  min uLW: 1.2669e+00, max uLW: 1.8202e+00
# For uBC,  min uLW: 1.3239e+00, max uLW: 1.8421e+00
# For uPDE, min uLW: 1.1254e+00, max uLW: 5.9207e+00
# For vIC,  min vLW: 1.4173e+00, max vLW: 1.9899e+00
# For vBC,  min vLW: 1.5080e+00, max vLW: 1.7733e+00
# For vPDE, min vLW: 1.0925e+00, max vLW: 2.6875e+00
# Iter 23000, Total: 1.0583e-04, Time: 48.94 secs
# IC: 5.9618e-05, PBC: 1.0329e-06, PDE: 4.5184e-05
# For uIC,  min uLW: 1.2714e+00, max uLW: 1.8207e+00
# For uBC,  min uLW: 1.3239e+00, max uLW: 1.8422e+00
# For uPDE, min uLW: 1.1259e+00, max uLW: 5.9211e+00
# For vIC,  min vLW: 1.4185e+00, max vLW: 2.0095e+00
# For vBC,  min vLW: 1.5081e+00, max vLW: 1.7734e+00
# For vPDE, min vLW: 1.0925e+00, max vLW: 2.6879e+00
# Iter 24000, Total: 9.2653e-05, Time: 45.66 secs
# IC: 5.4609e-05, PBC: 6.0644e-07, PDE: 3.7437e-05
# For uIC,  min uLW: 1.2759e+00, max uLW: 1.8217e+00
# For uBC,  min uLW: 1.3239e+00, max uLW: 1.8422e+00
# For uPDE, min uLW: 1.1263e+00, max uLW: 5.9211e+00
# For vIC,  min vLW: 1.4204e+00, max vLW: 2.0295e+00
# For vBC,  min vLW: 1.5082e+00, max vLW: 1.7734e+00
# For vPDE, min vLW: 1.0925e+00, max vLW: 2.6884e+00
# Iter 25000, Total: 7.6512e-03, Time: 47.55 secs
# IC: 1.5188e-03, PBC: 2.6140e-04, PDE: 5.8710e-03
# For uIC,  min uLW: 1.6880e+00, max uLW: 2.7298e+00
# For uBC,  min uLW: 1.5711e+00, max uLW: 2.0820e+00
# For uPDE, min uLW: 1.1531e+00, max uLW: 8.1344e+00
# For vIC,  min vLW: 1.8472e+00, max vLW: 2.8786e+00
# For vBC,  min vLW: 1.7838e+00, max vLW: 2.0497e+00
# For vPDE, min vLW: 1.0969e+00, max vLW: 3.9655e+00
# Iter 26000, Total: 6.3587e-03, Time: 46.85 secs
# IC: 7.4230e-04, PBC: 2.6360e-04, PDE: 5.3529e-03
# For uIC,  min uLW: 1.6891e+00, max uLW: 2.7299e+00
# For uBC,  min uLW: 1.5715e+00, max uLW: 2.0857e+00
# For uPDE, min uLW: 1.1533e+00, max uLW: 8.8725e+00
# For vIC,  min vLW: 1.8480e+00, max vLW: 2.8790e+00
# For vBC,  min vLW: 1.7843e+00, max vLW: 2.0507e+00
# For vPDE, min vLW: 1.0974e+00, max vLW: 4.3904e+00
# Iter 27000, Total: 4.2343e-03, Time: 45.45 secs
# IC: 4.5000e-04, PBC: 2.8262e-04, PDE: 3.5017e-03
# For uIC,  min uLW: 1.6902e+00, max uLW: 2.7300e+00
# For uBC,  min uLW: 1.5720e+00, max uLW: 2.0898e+00
# For uPDE, min uLW: 1.1543e+00, max uLW: 9.5707e+00
# For vIC,  min vLW: 1.8492e+00, max vLW: 2.8794e+00
# For vBC,  min vLW: 1.7847e+00, max vLW: 2.0524e+00
# For vPDE, min vLW: 1.0976e+00, max vLW: 4.6089e+00
# Iter 28000, Total: 2.4189e-03, Time: 48.73 secs
# IC: 2.9920e-04, PBC: 1.3465e-04, PDE: 1.9850e-03
# For uIC,  min uLW: 1.6912e+00, max uLW: 2.7302e+00
# For uBC,  min uLW: 1.5723e+00, max uLW: 2.0929e+00
# For uPDE, min uLW: 1.1655e+00, max uLW: 1.0435e+01
# For vIC,  min vLW: 1.8502e+00, max vLW: 2.8795e+00
# For vBC,  min vLW: 1.7851e+00, max vLW: 2.0532e+00
# For vPDE, min vLW: 1.0978e+00, max vLW: 4.7033e+00
# Iter 29000, Total: 1.5055e-03, Time: 48.25 secs
# IC: 2.1544e-04, PBC: 5.4629e-05, PDE: 1.2354e-03
# For uIC,  min uLW: 1.6920e+00, max uLW: 2.7303e+00
# For uBC,  min uLW: 1.5724e+00, max uLW: 2.0936e+00
# For uPDE, min uLW: 1.1684e+00, max uLW: 1.0808e+01
# For vIC,  min vLW: 1.8509e+00, max vLW: 2.8795e+00
# For vBC,  min vLW: 1.7853e+00, max vLW: 2.0533e+00
# For vPDE, min vLW: 1.0981e+00, max vLW: 4.7381e+00
# Iter 30000, Total: 1.0148e-03, Time: 48.14 secs
# IC: 1.7335e-04, PBC: 3.6704e-05, PDE: 8.0474e-04
# For uIC,  min uLW: 1.6930e+00, max uLW: 2.7303e+00
# For uBC,  min uLW: 1.5725e+00, max uLW: 2.0942e+00
# For uPDE, min uLW: 1.1718e+00, max uLW: 1.0995e+01
# For vIC,  min vLW: 1.8513e+00, max vLW: 2.8796e+00
# For vBC,  min vLW: 1.7854e+00, max vLW: 2.0535e+00
# For vPDE, min vLW: 1.0984e+00, max vLW: 4.7551e+00
# Iter 31000, Total: 7.2003e-04, Time: 47.66 secs
# IC: 1.5458e-04, PBC: 3.0123e-05, PDE: 5.3533e-04
# For uIC,  min uLW: 1.6942e+00, max uLW: 2.7303e+00
# For uBC,  min uLW: 1.5726e+00, max uLW: 2.0944e+00
# For uPDE, min uLW: 1.1740e+00, max uLW: 1.1094e+01
# For vIC,  min vLW: 1.8519e+00, max vLW: 2.8798e+00
# For vBC,  min vLW: 1.7856e+00, max vLW: 2.0538e+00
# For vPDE, min vLW: 1.0986e+00, max vLW: 4.7653e+00
# Iter 32000, Total: 5.2761e-04, Time: 47.27 secs
# IC: 1.4384e-04, PBC: 2.5255e-05, PDE: 3.5852e-04
# For uIC,  min uLW: 1.6959e+00, max uLW: 2.7306e+00
# For uBC,  min uLW: 1.5726e+00, max uLW: 2.0944e+00
# For uPDE, min uLW: 1.1762e+00, max uLW: 1.1144e+01
# For vIC,  min vLW: 1.8528e+00, max vLW: 2.8805e+00
# For vBC,  min vLW: 1.7857e+00, max vLW: 2.0540e+00
# For vPDE, min vLW: 1.0987e+00, max vLW: 4.7719e+00
# Iter 33000, Total: 3.9968e-04, Time: 47.96 secs
# IC: 1.3456e-04, PBC: 1.6216e-05, PDE: 2.4890e-04
# For uIC,  min uLW: 1.6984e+00, max uLW: 2.7309e+00
# For uBC,  min uLW: 1.5726e+00, max uLW: 2.0946e+00
# For uPDE, min uLW: 1.1794e+00, max uLW: 1.1164e+01
# For vIC,  min vLW: 1.8542e+00, max vLW: 2.8816e+00
# For vBC,  min vLW: 1.7857e+00, max vLW: 2.0544e+00
# For vPDE, min vLW: 1.0989e+00, max vLW: 4.7763e+00
# Iter 34000, Total: 3.2114e-04, Time: 47.30 secs
# IC: 1.2582e-04, PBC: 8.1565e-06, PDE: 1.8717e-04
# For uIC,  min uLW: 1.7016e+00, max uLW: 2.7311e+00
# For uBC,  min uLW: 1.5726e+00, max uLW: 2.0948e+00
# For uPDE, min uLW: 1.1838e+00, max uLW: 1.1170e+01
# For vIC,  min vLW: 1.8561e+00, max vLW: 2.8836e+00
# For vBC,  min vLW: 1.7857e+00, max vLW: 2.0549e+00
# For vPDE, min vLW: 1.0989e+00, max vLW: 4.7791e+00
# Iter 35000, Total: 2.7102e-04, Time: 47.57 secs
# IC: 1.1634e-04, PBC: 6.0651e-06, PDE: 1.4862e-04
# For uIC,  min uLW: 1.7062e+00, max uLW: 2.7313e+00
# For uBC,  min uLW: 1.5726e+00, max uLW: 2.0950e+00
# For uPDE, min uLW: 1.1879e+00, max uLW: 1.1171e+01
# For vIC,  min vLW: 1.8585e+00, max vLW: 2.8863e+00
# For vBC,  min vLW: 1.7857e+00, max vLW: 2.0552e+00
# For vPDE, min vLW: 1.0989e+00, max vLW: 4.7810e+00
# Iter 36000, Total: 2.3247e-04, Time: 48.18 secs
# IC: 1.0758e-04, PBC: 5.0257e-06, PDE: 1.1986e-04
# For uIC,  min uLW: 1.7125e+00, max uLW: 2.7313e+00
# For uBC,  min uLW: 1.5726e+00, max uLW: 2.0950e+00
# For uPDE, min uLW: 1.1910e+00, max uLW: 1.1172e+01
# For vIC,  min vLW: 1.8613e+00, max vLW: 2.8895e+00
# For vBC,  min vLW: 1.7857e+00, max vLW: 2.0554e+00
# For vPDE, min vLW: 1.0989e+00, max vLW: 4.7824e+00
# Iter 37000, Total: 2.0268e-04, Time: 48.97 secs
# IC: 1.0013e-04, PBC: 3.6274e-06, PDE: 9.8920e-05
# For uIC,  min uLW: 1.7208e+00, max uLW: 2.7313e+00
# For uBC,  min uLW: 1.5726e+00, max uLW: 2.0950e+00
# For uPDE, min uLW: 1.1932e+00, max uLW: 1.1172e+01
# For vIC,  min vLW: 1.8646e+00, max vLW: 2.8929e+00
# For vBC,  min vLW: 1.7857e+00, max vLW: 2.0554e+00
# For vPDE, min vLW: 1.0989e+00, max vLW: 4.7834e+00
# Iter 38000, Total: 1.7789e-04, Time: 47.41 secs
# IC: 9.3218e-05, PBC: 2.4562e-06, PDE: 8.2218e-05
# For uIC,  min uLW: 1.7313e+00, max uLW: 2.7313e+00
# For uBC,  min uLW: 1.5726e+00, max uLW: 2.0950e+00
# For uPDE, min uLW: 1.1932e+00, max uLW: 1.1172e+01
# For vIC,  min vLW: 1.8691e+00, max vLW: 2.8967e+00
# For vBC,  min vLW: 1.7857e+00, max vLW: 2.0554e+00
# For vPDE, min vLW: 1.0989e+00, max vLW: 4.7843e+00
# Iter 39000, Total: 1.5596e-04, Time: 45.25 secs
# IC: 8.6214e-05, PBC: 1.4714e-06, PDE: 6.8280e-05
# For uIC,  min uLW: 1.7440e+00, max uLW: 2.7313e+00
# For uBC,  min uLW: 1.5726e+00, max uLW: 2.0950e+00
# For uPDE, min uLW: 1.1932e+00, max uLW: 1.1172e+01
# For vIC,  min vLW: 1.8752e+00, max vLW: 2.9031e+00
# For vBC,  min vLW: 1.7857e+00, max vLW: 2.0558e+00
# For vPDE, min vLW: 1.0989e+00, max vLW: 4.7849e+00
# Iter 40000, Total: 1.3516e-04, Time: 43.67 secs
# IC: 7.8671e-05, PBC: 8.7628e-07, PDE: 5.5613e-05
# For uIC,  min uLW: 1.7581e+00, max uLW: 2.7313e+00
# For uBC,  min uLW: 1.5726e+00, max uLW: 2.0950e+00
# For uPDE, min uLW: 1.1932e+00, max uLW: 1.1172e+01
# For vIC,  min vLW: 1.8827e+00, max vLW: 2.9202e+00
# For vBC,  min vLW: 1.7857e+00, max vLW: 2.0560e+00
# For vPDE, min vLW: 1.0989e+00, max vLW: 4.7854e+00
# Iter 41000, Total: 1.1476e-04, Time: 43.62 secs
# IC: 6.9883e-05, PBC: 6.9580e-07, PDE: 4.4183e-05
# For uIC,  min uLW: 1.7731e+00, max uLW: 2.7391e+00
# For uBC,  min uLW: 1.5726e+00, max uLW: 2.0951e+00
# For uPDE, min uLW: 1.1932e+00, max uLW: 1.1172e+01
# For vIC,  min vLW: 1.8906e+00, max vLW: 2.9364e+00
# For vBC,  min vLW: 1.7857e+00, max vLW: 2.0563e+00
# For vPDE, min vLW: 1.0989e+00, max vLW: 4.7858e+00
# Iter 42000, Total: 9.4846e-05, Time: 44.66 secs
# IC: 5.8784e-05, PBC: 1.0316e-06, PDE: 3.5031e-05
# For uIC,  min uLW: 1.7876e+00, max uLW: 2.7895e+00
# For uBC,  min uLW: 1.5727e+00, max uLW: 2.0956e+00
# For uPDE, min uLW: 1.1932e+00, max uLW: 1.1172e+01
# For vIC,  min vLW: 1.8973e+00, max vLW: 2.9499e+00
# For vBC,  min vLW: 1.7857e+00, max vLW: 2.0563e+00
# For vPDE, min vLW: 1.0989e+00, max vLW: 4.7861e+00
# Iter 43000, Total: 7.1843e-05, Time: 44.55 secs
# IC: 4.3288e-05, PBC: 7.7575e-07, PDE: 2.7778e-05
# For uIC,  min uLW: 1.7985e+00, max uLW: 2.8250e+00
# For uBC,  min uLW: 1.5728e+00, max uLW: 2.0966e+00
# For uPDE, min uLW: 1.1932e+00, max uLW: 1.1172e+01
# For vIC,  min vLW: 1.9013e+00, max vLW: 2.9591e+00
# For vBC,  min vLW: 1.7857e+00, max vLW: 2.0563e+00
# For vPDE, min vLW: 1.0989e+00, max vLW: 4.7861e+00
# Iter 44000, Total: 5.1266e-05, Time: 44.62 secs
# IC: 2.7104e-05, PBC: 5.4425e-07, PDE: 2.3617e-05
# For uIC,  min uLW: 1.8021e+00, max uLW: 2.8412e+00
# For uBC,  min uLW: 1.5729e+00, max uLW: 2.0968e+00
# For uPDE, min uLW: 1.1932e+00, max uLW: 1.1172e+01
# For vIC,  min vLW: 1.9026e+00, max vLW: 2.9633e+00
# For vBC,  min vLW: 1.7857e+00, max vLW: 2.0563e+00
# For vPDE, min vLW: 1.0989e+00, max vLW: 4.7861e+00
# Iter 45000, Total: 3.8152e-05, Time: 44.84 secs
# IC: 1.6982e-05, PBC: 4.4412e-07, PDE: 2.0726e-05
# For uIC,  min uLW: 1.8030e+00, max uLW: 2.8469e+00
# For uBC,  min uLW: 1.5729e+00, max uLW: 2.0968e+00
# For uPDE, min uLW: 1.1932e+00, max uLW: 1.1172e+01
# For vIC,  min vLW: 1.9030e+00, max vLW: 2.9648e+00
# For vBC,  min vLW: 1.7857e+00, max vLW: 2.0563e+00
# For vPDE, min vLW: 1.0989e+00, max vLW: 4.7861e+00
# Iter 46000, Total: 3.0324e-05, Time: 44.73 secs
# IC: 1.1517e-05, PBC: 3.9094e-07, PDE: 1.8416e-05
# For uIC,  min uLW: 1.8032e+00, max uLW: 2.8489e+00
# For uBC,  min uLW: 1.5729e+00, max uLW: 2.0968e+00
# For uPDE, min uLW: 1.1932e+00, max uLW: 1.1172e+01
# For vIC,  min vLW: 1.9031e+00, max vLW: 2.9654e+00
# For vBC,  min vLW: 1.7857e+00, max vLW: 2.0563e+00
# For vPDE, min vLW: 1.0989e+00, max vLW: 4.7861e+00
# Iter 47000, Total: 2.5333e-05, Time: 44.19 secs
# IC: 8.3577e-06, PBC: 3.7031e-07, PDE: 1.6605e-05
# For uIC,  min uLW: 1.8032e+00, max uLW: 2.8497e+00
# For uBC,  min uLW: 1.5729e+00, max uLW: 2.0968e+00
# For uPDE, min uLW: 1.1932e+00, max uLW: 1.1172e+01
# For vIC,  min vLW: 1.9031e+00, max vLW: 2.9657e+00
# For vBC,  min vLW: 1.7857e+00, max vLW: 2.0563e+00
# For vPDE, min vLW: 1.0989e+00, max vLW: 4.7861e+00
# Iter 48000, Total: 2.1922e-05, Time: 42.58 secs
# IC: 6.3614e-06, PBC: 3.7024e-07, PDE: 1.5191e-05
# For uIC,  min uLW: 1.8032e+00, max uLW: 2.8500e+00
# For uBC,  min uLW: 1.5729e+00, max uLW: 2.0968e+00
# For uPDE, min uLW: 1.1932e+00, max uLW: 1.1172e+01
# For vIC,  min vLW: 1.9031e+00, max vLW: 2.9658e+00
# For vBC,  min vLW: 1.7857e+00, max vLW: 2.0563e+00
# For vPDE, min vLW: 1.0989e+00, max vLW: 4.7861e+00
# Iter 49000, Total: 1.9456e-05, Time: 43.01 secs
# IC: 5.0189e-06, PBC: 3.7833e-07, PDE: 1.4059e-05
# For uIC,  min uLW: 1.8032e+00, max uLW: 2.8501e+00
# For uBC,  min uLW: 1.5729e+00, max uLW: 2.0968e+00
# For uPDE, min uLW: 1.1932e+00, max uLW: 1.1172e+01
# For vIC,  min vLW: 1.9031e+00, max vLW: 2.9658e+00
# For vBC,  min vLW: 1.7857e+00, max vLW: 2.0563e+00
# For vPDE, min vLW: 1.0989e+00, max vLW: 4.7861e+00
# Iter 50000, Total: 1.7581e-05, Time: 43.63 secs
# IC: 4.0764e-06, PBC: 3.8574e-07, PDE: 1.3119e-05
# For uIC,  min uLW: 1.8032e+00, max uLW: 2.8501e+00
# For uBC,  min uLW: 1.5729e+00, max uLW: 2.0968e+00
# For uPDE, min uLW: 1.1932e+00, max uLW: 1.1172e+01
# For vIC,  min vLW: 1.9031e+00, max vLW: 2.9658e+00
# For vBC,  min vLW: 1.7857e+00, max vLW: 2.0563e+00
# For vPDE, min vLW: 1.0989e+00, max vLW: 4.7861e+00
# Starting with L-BFGS

# %%
t = np.linspace(tlo, thi, 201)
x = np.linspace(xlo, xhi, 501)
T, X = np.meshgrid(t, x)
pts_flat = np.hstack((T.flatten()[:, None], X.flatten()[:, None]))
u_pred, v_pred = model.predict(pts_flat)           
u_pred = griddata(pts_flat, u_pred.flatten(), (T, X), method='cubic')
v_pred = griddata(pts_flat, v_pred.flatten(), (T, X), method='cubic')

# %% [markdown]
# ## Visualizations

# %%
data = scipy.io.loadmat('/Users/abraham/Desktop/PINN/New_Data/NLS_1D_t2.mat')
t = data['t'].flatten()[:,None]
x2 = data['x'].flatten()[:,None]
u_sol = np.real(data['Exact']).T
v_sol = np.imag(data['Exact']).T

# %%
fig = plt.figure(figsize=(11, 5))
ax = fig.add_subplot(1, 1, 1)
#
ax.plot(ptsPDE[:, 0], ptsPDE[:, 1], 
    'rd', label = 'PDE Data (%d points)' % (ptsPDE.shape[0]), 
    markersize = 4,  # marker size doubled
    clip_on = False,
    alpha=1.0
)

ax.plot(ptsIC[:, 0], ptsIC[:, 1], 
    'bd', label = 'IC Data (%d points)' % (ptsIC.shape[0]), 
    markersize = 4,  # marker size doubled
    clip_on = False,
    alpha=1.0
)


ax.plot(ptsBC[:, 0], ptsBC[:, 1], 
    'gd', label = 'BC Data (%d points)' % (ptsBC.shape[0]), 
    markersize = 4,  # marker size doubled
    clip_on = False,
    alpha=1.0
)

ax.set_xlabel('$t$', size=15)
ax.set_ylabel('$x$', size=15)
ax.legend(
    loc='upper center', 
    bbox_to_anchor=(0.9, -0.05), 
    ncol=5, 
    frameon=False, 
    prop={'size': 15}
)
ax.legend()
ax.set_title('Points', fontsize = 15) # font size doubled
ax.tick_params(labelsize=12)
#
plt.show()

# %%
####### Row 1: u(t,x) slices ################## 

""" The aesthetic setting has changed. """

fig = plt.figure(figsize=(18, 6))
#
ax = plt.subplot(1, 3, 1)
ax.plot(x2, u_sol[0,:], 'bo-', linewidth = 2, label = 'Exact')       
ax.plot(x, u_pred[:, 0], 'rx--', linewidth = 2, label = 'u')
ax.set_xlabel('$x$')
ax.set_ylabel('$u(t,x)$')    
ax.set_title('$t = %.1f$' %(t[0]), fontsize = 24)


plt.locator_params(axis = 'y', nbins = 5)
plt.locator_params(axis = 'x', nbins = 5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(24)

ax = plt.subplot(1, 3, 2)
ax.plot(x,u_sol[100,:], 'bo-', linewidth = 2, label = 'Exact')       
ax.plot(x, u_pred[:, 100], 'rx--', linewidth = 2, label = 'u')

ax.set_xlabel('x')




ax.set_title('$t = %.1f$' %(t[100]), fontsize = 24)
ax.legend(
    loc='upper center', 
    bbox_to_anchor=(0.5, -0.15), 
    ncol=5, 
    frameon=False, 
    prop={'size': 24}
)
plt.locator_params(axis = 'y', nbins = 5)
plt.locator_params(axis = 'x', nbins = 5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(24)

ax = plt.subplot(1, 3, 3)
ax.plot(x,u_sol[200,:], 'bo-', linewidth = 2, label = 'Exact')       
ax.plot(x, u_pred[:, 200], 'rx--', linewidth = 2, label = 'u')

ax.set_xlabel('$x$')




ax.set_title('$t = %.1f$' %(t[200]), fontsize = 24)
plt.locator_params(axis = 'y', nbins = 5)
plt.locator_params(axis = 'x', nbins = 5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(24)

plt.show()

# %%
fig = plt.figure(figsize=(18, 6))
#
ax = plt.subplot(1, 3, 1)
ax.plot(x2, v_sol[0,:], 'bo-', linewidth = 2, label = 'Exact')       
ax.plot(x, v_pred[:, 0], 'rx--', linewidth = 2, label = 'u')
ax.set_xlabel('$x$')
ax.set_ylabel('$v(t,x)$')    
ax.set_title('$t = %.1f$' %(t[0]), fontsize = 24)


plt.locator_params(axis = 'y', nbins = 5)
plt.locator_params(axis = 'x', nbins = 5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(24)

ax = plt.subplot(1, 3, 2)
ax.plot(x,v_sol[100,:], 'bo-', linewidth = 2, label = 'Exact')       
ax.plot(x, v_pred[:, 100], 'rx--', linewidth = 2, label = 'u')

ax.set_xlabel('x')




ax.set_title('$t = %.1f$' %(t[100]), fontsize = 24)
ax.legend(
    loc='upper center', 
    bbox_to_anchor=(0.5, -0.15), 
    ncol=5, 
    frameon=False, 
    prop={'size': 24}
)
plt.locator_params(axis = 'y', nbins = 5)
plt.locator_params(axis = 'x', nbins = 5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(24)

ax = plt.subplot(1, 3, 3)
ax.plot(x,v_sol[200,:], 'bo-', linewidth = 2, label = 'Exact')       
ax.plot(x, v_pred[:, 200], 'rx--', linewidth = 2, label = 'u')

ax.set_xlabel('$x$')




ax.set_title('$t = %.1f$' %(t[200]), fontsize = 24)
plt.locator_params(axis = 'y', nbins = 5)
plt.locator_params(axis = 'x', nbins = 5)
for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
             ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(24)

plt.show()

# %%
def relative_error_l2(pred,exact):
    error_l2 = np.sqrt(np.sum(np.power(pred - exact,2)))
    relative = error_l2/np.sqrt(np.sum(np.power(exact,2)))
    return relative
def relative_error_l1(pred,exact):
    error_l1 = np.sum(np.abs(pred-exact))
    relative = error_l1/np.sum(np.abs(exact))
    return relative
def relative_error_linf(pred,exact):
    error_linf = np.max(np.abs(pred-exact))
    relative = error_linf/np.max(np.abs(exact))
    return relative

# %%
print(f'l2: {relative_error_l2(u_pred.T,u_sol)}')
print(f'l1: {relative_error_l1(u_pred.T,u_sol)}')
print(f'linf: {relative_error_linf(u_pred.T,u_sol)}')
# Out:
# l2: 0.0424980466802807
# l1: 0.03077651477436015
# linf: 0.12271304196006816

# %%
print(f'l2: {relative_error_l2(v_pred.T,v_sol)}')
print(f'l1: {relative_error_l1(v_pred.T,v_sol)}')
print(f'linf: {relative_error_linf(v_pred.T,v_sol)}')

# %%
fig = plt.figure(figsize=(24, 6))

ax = plt.subplot(1, 3, 1)
h = ax.imshow(u_sol.T, interpolation='nearest', cmap='rainbow', 
              extent=[tlo, thi, x.min(), x.max()], 
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=24) 







ax.set_xlabel('$t$', size=24)
ax.set_ylabel('$x$', size=24)

ax.set_title('$GS: u_{exact}(t,x)$', fontsize = 24) # font size doubled
ax.tick_params(labelsize=24)

ax = plt.subplot(1, 3, 2)
h = ax.imshow(u_pred, interpolation='nearest', cmap='rainbow', 
              extent=[tlo, thi, x.min(), x.max()], 
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=24) 




ax.set_xlabel('$t$', size=24)


ax.set_title('$NLS: u_{pred}(t,x)$', fontsize = 24) # font size doubled
ax.tick_params(labelsize=24)

ax = plt.subplot(1, 3, 3)
h = ax.imshow(np.abs(u_pred-u_sol.T), interpolation='nearest', cmap='rainbow', 
              extent=[tlo, thi, x.min(), x.max()], 
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=24) 




ax.set_xlabel('$t$', size=24)


ax.set_title('$NLS(Error): u(t,x)$', fontsize = 24) # font size doubled
ax.tick_params(labelsize=24)


plt.show()

# %%
fig = plt.figure(figsize=(24, 6))

ax = plt.subplot(1, 3, 1)
h = ax.imshow(v_sol.T, interpolation='nearest', cmap='rainbow', 
              extent=[tlo, thi, x.min(), x.max()], 
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=24) 







ax.set_xlabel('$t$', size=24)
ax.set_ylabel('$x$', size=24)

ax.set_title('$NLS: v_{exact}(t,x)$', fontsize = 24) # font size doubled
ax.tick_params(labelsize=24)

ax = plt.subplot(1, 3, 2)
h = ax.imshow(v_pred, interpolation='nearest', cmap='rainbow', 
              extent=[tlo, thi, x.min(), x.max()], 
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=24) 




ax.set_xlabel('$t$', size=24)

ax.set_xticks([0 ,0.5 ,1])
ax.set_yticks([-1 ,0 ,1])
ax.set_title('$NLS: v_{pred}(t,x)$', fontsize = 24) # font size doubled
ax.tick_params(labelsize=24)

ax = plt.subplot(1, 3, 3)
h = ax.imshow(np.abs(v_pred-v_sol.T), interpolation='nearest', cmap='rainbow', 
              extent=[tlo, thi, x.min(), x.max()], 
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.10)
cbar = fig.colorbar(h, cax=cax)
cbar.ax.tick_params(labelsize=24) 




ax.set_xlabel('$t$', size=24)

ax.set_xticks([0 ,0.5 ,1])
ax.set_yticks([-1 ,0 ,1])
ax.set_title('$NLS(Error): v(t,x)$', fontsize = 24) # font size doubled
ax.tick_params(labelsize=24)


plt.show()
